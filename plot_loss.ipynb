# %%
import pandas as pd
import seaborn as sns

# %%
loss_df = pd.read_csv("output/loss_HMS_2.csv")

# %%
loss_df
# Out:
#       Unnamed: 0  epoch  batch          time  total_loss    loss_1    loss_2  \
# 0              0    1.0    0.0     16.473559    1.193267  1.057510  1.357573
# 1              1    1.0    1.0     26.583376    1.077747  0.949907  1.278401
# 2              2    1.0    2.0     34.757307    1.242711  1.124311  1.183999
# 3              3    1.0    3.0     42.584618    0.852545  0.728514  1.240306
# 4              4    1.0    4.0     49.924070    0.806790  0.681311  1.254784
# ...          ...    ...    ...           ...         ...       ...       ...
# 3495        3495  500.0    2.0  30949.544756    0.480016  0.366856  1.131595
# 3496        3496  500.0    3.0  30957.144579    0.428091  0.313744  1.143466
# 3497        3497  500.0    4.0  30964.944344    0.499146  0.393010  1.061357
# 3498        3498  500.0    5.0  30972.271759    0.405776  0.294168  1.116080
# 3499        3499  500.0    6.0  30975.946221    0.960724  0.855802  1.049222
#
#       accuracy_1  accuracy_2
# 0       0.553783    0.212883
# 1       0.404293    0.212399
# 2       0.217396    0.356600
# 3       0.425782    0.265139
# 4       0.438173    0.273402
# ...          ...         ...
# 3495    0.791505    0.314284
# 3496    0.790548    0.297925
# 3497    0.819887    0.391383
# 3498    0.813685    0.319432
# 3499    0.580333    0.418112
#
# [3500 rows x 9 columns]
#       Unnamed: 0  epoch  batch          time  total_loss    loss_1    loss_2  \
# 0              0    1.0    0.0     16.473559    1.193267  1.057510  1.357573
# 1              1    1.0    1.0     26.583376    1.077747  0.949907  1.278401
# 2              2    1.0    2.0     34.757307    1.242711  1.124311  1.183999
# 3              3    1.0    3.0     42.584618    0.852545  0.728514  1.240306
# 4              4    1.0    4.0     49.924070    0.806790  0.681311  1.254784
# ...          ...    ...    ...           ...         ...       ...       ...
# 3495        3495  500.0    2.0  30949.544756    0.480016  0.366856  1.131595
# 3496        3496  500.0    3.0  30957.144579    0.428091  0.313744  1.143466
# 3497        3497  500.0    4.0  30964.944344    0.499146  0.393010  1.061357
# 3498        3498  500.0    5.0  30972.271759    0.405776  0.294168  1.116080
# 3499        3499  500.0    6.0  30975.946221    0.960724  0.855802  1.049222
#
#       accuracy_1  accuracy_2
# 0       0.553783    0.212883
# 1       0.404293    0.212399
# 2       0.217396    0.356600
# 3       0.425782    0.265139
# 4       0.438173    0.273402
# ...          ...         ...
# 3495    0.791505    0.314284
# 3496    0.790548    0.297925
# 3497    0.819887    0.391383
# 3498    0.813685    0.319432
# 3499    0.580333    0.418112
#
# [3500 rows x 9 columns]

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x="epoch", y="accuracy_1",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='accuracy_1'>
# <AxesSubplot:xlabel='epoch', ylabel='accuracy_1'>

# %%
sns.lineplot(x="epoch", y="accuracy_2",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='accuracy_2'>
# <AxesSubplot:xlabel='epoch', ylabel='accuracy_2'>

# %%
sns.lineplot(x="epoch", y="loss_1",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='loss_1'>
# <AxesSubplot:xlabel='epoch', ylabel='loss_1'>

# %%
sns.lineplot(x="epoch", y="loss_2",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='loss_2'>
# <AxesSubplot:xlabel='epoch', ylabel='loss_2'>
