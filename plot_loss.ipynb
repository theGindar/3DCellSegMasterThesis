# %%
import pandas as pd
import seaborn as sns

# %%
loss_df = pd.read_csv("output/loss_HMS_3.csv")

# %%
loss_df
# Out:
#       Unnamed: 0  epoch  batch          time  total_loss    loss_1    loss_2  \
# 0              0    1.0    0.0     22.614636    1.999753  1.162590  0.837163
# 1              1    1.0    1.0     35.718544    1.756751  0.950572  0.806178
# 2              2    1.0    2.0     47.596771    1.800339  0.947934  0.852405
# 3              3    1.0    3.0     58.445230    1.717055  0.918489  0.798566
# 4              4    1.0    4.0     69.312754    1.505795  0.718322  0.787473
# ...          ...    ...    ...           ...         ...       ...       ...
# 3495        3495  500.0    2.0  42538.330168    1.108277  0.386936  0.721340
# 3496        3496  500.0    3.0  42549.300362    1.146717  0.509245  0.637473
# 3497        3497  500.0    4.0  42560.187179    1.016489  0.319914  0.696575
# 3498        3498  500.0    5.0  42572.209432    0.989019  0.311301  0.677718
# 3499        3499  500.0    6.0  42577.327191    1.029610  0.225952  0.803658
#
#       accuracy_1  accuracy_2
# ...

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x="epoch", y="accuracy_1",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='accuracy_1'>

# %%
sns.lineplot(x="epoch", y="accuracy_2",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='accuracy_2'>

# %%
sns.lineplot(x="epoch", y="loss_1",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='loss_1'>

# %%
sns.lineplot(x="epoch", y="loss_2",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='loss_2'>
