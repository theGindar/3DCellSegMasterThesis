# %%
import pandas as pd
import seaborn as sns

# %%
loss_df = pd.read_csv("output/loss_HMS_2.csv")

# %%
loss_df
# Out:
#       Unnamed: 0  epoch  batch          time  total_loss    loss_1    loss_2  \
# 0              0    1.0    0.0     20.576364    1.265840  1.191800  0.740401
# 1              1    1.0    1.0     29.446824    0.990739  0.923717  0.670219
# 2              2    1.0    2.0     37.814658    0.873828  0.803557  0.702714
# 3              3    1.0    3.0     44.642354    0.914580  0.846924  0.676558
# 4              4    1.0    4.0     51.826322    0.665503  0.593520  0.719823
# ...          ...    ...    ...           ...         ...       ...       ...
# 3495        3495  500.0    2.0  29637.892634    0.369004  0.302649  0.663547
# 3496        3496  500.0    3.0  29645.095259    0.407077  0.343704  0.633729
# 3497        3497  500.0    4.0  29652.352938    0.446285  0.387834  0.584509
# 3498        3498  500.0    5.0  29659.471603    0.388406  0.324526  0.638795
# 3499        3499  500.0    6.0  29662.742242    0.431686  0.372360  0.593262
#
#       accuracy_1  accuracy_2
# 0       0.310672    0.259598
# 1       0.467999    0.329781
# 2       0.468094    0.297285
# 3       0.444086    0.323441
# 4       0.555209    0.280176
# ...          ...         ...
# 3495    0.811039    0.336452
# 3496    0.810718    0.366270
# 3497    0.803561    0.415490
# 3498    0.815439    0.361205
# 3499    0.831175    0.406736
#
# [3500 rows x 9 columns]

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x="epoch", y="accuracy_1",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='accuracy_1'>

# %%
sns.lineplot(x="epoch", y="accuracy_2",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='accuracy_2'>

# %%
sns.lineplot(x="epoch", y="loss_1",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='loss_1'>

# %%
sns.lineplot(x="epoch", y="loss_2",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='loss_2'>
