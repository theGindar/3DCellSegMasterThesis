# %%
import pandas as pd
import seaborn as sns

# %%
loss_df = pd.read_csv("output/loss_HMS_3.csv")

# %%
loss_df
# Out:
#       Unnamed: 0  epoch  batch          time  total_loss    loss_1    loss_2  \
# 0              0    1.0    0.0     22.181013    1.872809  1.052195  0.820614
# 1              1    1.0    1.0     35.679450    1.773293  0.967748  0.805545
# 2              2    1.0    2.0     48.543494    1.769442  0.955414  0.814028
# 3              3    1.0    3.0     60.726707    1.874568  1.020863  0.853705
# 4              4    1.0    4.0     71.965506    1.819406  0.979647  0.839759
# ...          ...    ...    ...           ...         ...       ...       ...
# 3495        3495  500.0    2.0  43090.686521    1.027053  0.340460  0.686593
# 3496        3496  500.0    3.0  43101.841024    1.006175  0.329929  0.676246
# 3497        3497  500.0    4.0  43112.866306    0.987501  0.362487  0.625014
# 3498        3498  500.0    5.0  43124.238237    1.067492  0.305518  0.761974
# 3499        3499  500.0    6.0  43129.151081    1.157775  0.317477  0.840298
#
#       accuracy_1  accuracy_2
# 0       0.337281    0.266356
# 1       0.413057    0.276946
# 2       0.443635    0.241093
# 3       0.440060    0.224561
# 4       0.479291    0.225292
# ...          ...         ...
# 3495    0.791024    0.377675
# 3496    0.779062    0.374161
# 3497    0.842868    0.429329
# 3498    0.780627    0.307093
# 3499    0.698618    0.252115
#
# [3500 rows x 9 columns]

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x="epoch", y="accuracy_1",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='accuracy_1'>

# %%
sns.lineplot(x="epoch", y="accuracy_2",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='accuracy_2'>

# %%
sns.lineplot(x="epoch", y="loss_1",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='loss_1'>

# %%
sns.lineplot(x="epoch", y="loss_2",
             data=loss_df)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='loss_2'>
