# %% [markdown]
# ## pipeline

# %%
import numpy as np
import os
import pickle
import copy
import edt
import matplotlib.pyplot as plt
import time
import cv2
import pandas as pd
from sklearn.metrics.cluster import adjusted_rand_score
from skimage.metrics import adapted_rand_error

import torch
from torch import from_numpy as from_numpy
from torchsummary import summary

from func.run_pipeline_super_vox import segment_super_vox_3_channel, semantic_segment_crop_and_cat_3_channel_output, \
img_3d_erosion_or_expansion, segment_super_vox_2_channel, semantic_segment_crop_and_cat_2_channel_output, \
generate_super_vox_by_watershed, get_outlayer_of_a_3d_shape, get_crop_by_pixel_val, Cluster_Super_Vox, assign_boudary_voxels_to_cells_with_watershed, \
delete_too_small_cluster, reassign
from func.run_pipeline import segment, assign_boudary_voxels_to_cells, dbscan_of_seg, semantic_segment_crop_and_cat
from func.cal_accuracy import IOU_and_Dice_Accuracy, VOI
from func.network import VoxResNet, CellSegNet_basic_lite
from func.unet_3d_basic import UNet3D_basic
from func.ultis import save_obj, load_obj

# %% [markdown]
# ### init model

# %%
# model=UNet3D_basic(in_channels = 1, out_channels = 3)
# load_path=''
# model=VoxResNet(input_channel=1, n_classes=3, output_func = "softmax")
# load_path=''
model=CellSegNet_basic_lite(input_channel=1, n_classes=3, output_func = "softmax")
load_path='output/model_Ovules.pkl'
checkpoint = torch.load(load_path)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# CellSegNet_basic_lite(
#   (conv1): Conv3d(1, 16, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#   (conv2): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (bnorm1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#   (resmodule1): ResModule(
#     (batchnorm_module): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_module): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   )
#   (conv4): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#   (resmodule2): ResModule(
#     (batchnorm_module): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_module): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   )
#   (conv5): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#   (resmodule3): ResModule(
#     (batchnorm_module): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_module): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   )
#   (deconv1): ConvTranspose3d(64, 64, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#   (bnorm2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv2): ConvTranspose3d(64, 64, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#   (bnorm3): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv3): ConvTranspose3d(64, 32, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#   (bnorm4): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv3d(32, 3, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
# )

# %% [markdown]
# ### dataset info

# %%
Ovules_data_dict = load_obj("dataset_info/Ovules_dataset_info")

# %%
Ovules_data_dict
# Out:
# {'train': {'N_509_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_509_ds2x.npz',
#   'N_449_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_449_ds2x.npz',
#   'N_536_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_536_ds2x.npz',
#   'N_454_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_454_ds2x.npz',
#   'N_422_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_422_ds2x.npz',
#   'N_416_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_416_ds2x.npz',
#   'N_428_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_428_ds2x.npz',
#   'N_512_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_512_ds2x.npz',
#   'N_425_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_425_ds2x.npz',
#   'N_405_B_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_405_B_ds2x.npz',
#   'N_458_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_458_ds2x.npz',
#   'N_445_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_445_ds2x.npz',
#   'N_487_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_487_ds2x.npz',
#   'N_517_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_517_ds2x.npz',
#   'N_457_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_457_ds2x.npz',
#   'N_534_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_534_ds2x.npz',
#   'N_535_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_535_ds2x.npz',
#   'N_440_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_440_ds2x.npz',
#   'N_404_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_404_ds2x.npz',
#   'N_451_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_451_ds2x.npz',
#   'N_450_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_450_ds2x.npz',
#   'N_405_A_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_405_A_ds2x.npz',
#   'N_420_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/val/N_420_ds2x.npz',
#   'N_464_ds2x.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/val/N_464_ds2x.npz'},
#  'test': {'N_441_final_crop_ds2.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_441_final_crop_ds2.npz',
#   'N_522_final_crop_ds2.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_522_final_crop_ds2.npz',
#   'N_511_final_crop_ds2.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_511_final_crop_ds2.npz',
#   'N_435_final_crop_ds2.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_435_final_crop_ds2.npz',
#   'N_294_final_crop_ds2.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_294_final_crop_ds2.npz',
#   'N_590_final_crop_ds2.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_590_final_crop_ds2.npz',
#   'N_593_final_crop_ds2.npz': 'data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_593_final_crop_ds2.npz'}}

# %% [markdown]
# ### seg one img

# %% [markdown]
# parameter setting

# %%
# we do not input the whole raw image to the model one time but input raw image crops
crop_cube_size=128
stride=64

# hyperparameter for TASCAN, min touching area of two super pixels if they belong to the same cell
min_touching_area=30

# %% [markdown]
# choose a test image and load it

# %%
print("there are test imgs: "+str(Ovules_data_dict['test'].keys()))
case = 'N_435_final_crop_ds2.npz'
print("for test case "+str(case)+" : "+str(Ovules_data_dict['test'][case]))
# Out:
# there are test imgs: dict_keys(['N_441_final_crop_ds2.npz', 'N_522_final_crop_ds2.npz', 'N_511_final_crop_ds2.npz', 'N_435_final_crop_ds2.npz', 'N_294_final_crop_ds2.npz', 'N_590_final_crop_ds2.npz', 'N_593_final_crop_ds2.npz'])
# for test case N_435_final_crop_ds2.npz : data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_435_final_crop_ds2.npz

# %%
hf = np.load(Ovules_data_dict['test'][case])
raw_img = np.array(hf["raw"], dtype=np.float)
hand_seg = np.array(hf["ins"], dtype=np.float)
boundary_gt = np.array(hf["boundary"], dtype=np.float)
foreground_gt = np.array(hf["foreground"], dtype=np.float)

print("raw_img shape: "+str(raw_img.shape))
print("hand_seg shape: "+str(hand_seg.shape))
raw_img_shape = raw_img.shape
hand_seg_shape = hand_seg.shape
# Out:
# /var/folders/qq/9q6wphrj19z8xt4qcffm8df80000gn/T/ipykernel_19417/2859134447.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   raw_img = np.array(hf["raw"], dtype=np.float)
# /var/folders/qq/9q6wphrj19z8xt4qcffm8df80000gn/T/ipykernel_19417/2859134447.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hand_seg = np.array(hf["ins"], dtype=np.float)
# /var/folders/qq/9q6wphrj19z8xt4qcffm8df80000gn/T/ipykernel_19417/2859134447.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   boundary_gt = np.array(hf["boundary"], dtype=np.float)
# /var/folders/qq/9q6wphrj19z8xt4qcffm8df80000gn/T/ipykernel_19417/2859134447.py:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   foreground_gt = np.array(hf["foreground"], dtype=np.float)
# raw_img shape: (194, 550, 555)
# hand_seg shape: (194, 550, 555)

# %% [markdown]
# feed raw image crops to the model

# %%
# feed the raw img to the model
print('Feed raw img to model. Use different transposes')
raw_img_size=raw_img.shape
    
seg_foreground_comp = np.zeros(raw_img_size)
seg_boundary_comp = np.zeros(raw_img_size)

transposes = [[0,1,2]]#,[2,0,1],[0,2,1]]
reverse_transposes = [[0,1,2]]#,[1,2,0],[0,2,1]]

for idx, transpose in enumerate(transposes):
    print(str(idx+1)+": Transpose the image to be: "+str(transpose))
    with torch.no_grad():
        seg_img=\
        semantic_segment_crop_and_cat_3_channel_output(raw_img.transpose(transpose), model, device, crop_cube_size=crop_cube_size, stride=stride)
    seg_img_background=seg_img['background']
    seg_img_boundary=seg_img['boundary']
    seg_img_foreground=seg_img['foreground']
    torch.cuda.empty_cache()
    
    # argmax
    print('argmax', end='\r')
    seg=[]
    seg.append(seg_img_background)
    seg.append(seg_img_boundary)
    seg.append(seg_img_foreground)
    seg=np.array(seg)
    seg_argmax=np.argmax(seg, axis=0)
    # probability map to 0 1 segment
    seg_background=np.zeros(seg_img_background.shape)
    seg_background[np.where(seg_argmax==0)]=1
    seg_foreground=np.zeros(seg_img_foreground.shape)
    seg_foreground[np.where(seg_argmax==2)]=1
    seg_boundary=np.zeros(seg_img_boundary.shape)
    seg_boundary[np.where(seg_argmax==1)]=1
        
    seg_background=seg_background.transpose(reverse_transposes[idx])
    seg_foreground=seg_foreground.transpose(reverse_transposes[idx])
    seg_boundary=seg_boundary.transpose(reverse_transposes[idx])
        
    seg_foreground_comp+=seg_foreground
    seg_boundary_comp+=seg_boundary
print("Get model semantic seg by combination")
seg_boundary_comp = np.array(seg_boundary_comp>0, dtype=np.int)
seg_foreground_comp = np.array(seg_foreground_comp>0, dtype=np.int)
seg_foreground_comp[seg_boundary_comp>0]=0
seg_background_comp = np.array(1 - seg_foreground_comp - seg_boundary_comp>0, dtype=np.int)
# Out:
# Feed raw img to model. Use different transposes
# 1: Transpose the image to be: [0, 1, 2]
# s of segment_3d_img: 99%Get model semantic seg by combination
# /var/folders/qq/9q6wphrj19z8xt4qcffm8df80000gn/T/ipykernel_19417/2139664496.py:44: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   seg_boundary_comp = np.array(seg_boundary_comp>0, dtype=np.int)
# /var/folders/qq/9q6wphrj19z8xt4qcffm8df80000gn/T/ipykernel_19417/2139664496.py:45: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   seg_foreground_comp = np.array(seg_foreground_comp>0, dtype=np.int)
# /var/folders/qq/9q6wphrj19z8xt4qcffm8df80000gn/T/ipykernel_19417/2139664496.py:47: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   seg_background_comp = np.array(1 - seg_foreground_comp - seg_boundary_comp>0, dtype=np.int)

# %%
with open("seg_boundary_comp.pickle", "wb") as f:
    pickle.dump(seg_background_comp, f)
with open("seg_foreground_comp.pickle", "wb") as f:
    pickle.dump(seg_foreground_comp, f)
with open("seg_background_comp.pickle", "wb") as f:
    pickle.dump(seg_background_comp, f)

# %%
N=80

plt.figure()
plt.title("raw_img")
plt.imshow(raw_img[N,:,:])
plt.figure()
plt.title("hand_seg")
plt.imshow(reassign(hand_seg[N,:,:]))
plt.figure()
plt.title("model_seg_foreground")
plt.imshow(seg_foreground_comp[N,:,:])
# Out:
# 6reassign unique numbers progress: 0.8177966101694916

# %% [markdown]
# TASCAN

# %% [markdown]
# generate super vox by watershed

# %%
# Generate super vox by watershed
how_close_are_the_super_vox_to_boundary=2
min_touching_percentage=0.51
#min_touching_percentage=0.02

seg_foreground_erosion=1-img_3d_erosion_or_expansion(1-seg_foreground_comp, kernel_size=how_close_are_the_super_vox_to_boundary+1, device=device)
seg_foreground_super_voxel_by_ws = generate_super_vox_by_watershed(seg_foreground_erosion, connectivity=min_touching_area)

# %%
print("There are "+str(len(np.unique(seg_foreground_super_voxel_by_ws)))+" super voxels")
# Out:
# There are 5829 super voxels

# %%
seg_foreground_super_voxel_by_ws.shape
# Out:
# (194, 550, 555)

# %%
plt.figure(figsize=(20,20))
plt.title("supervoxels")
plt.imshow(seg_foreground_super_voxel_by_ws[N,:,:])

# %% [markdown]
# super voxel clustearing

# %%
# Super voxel clustering
cluster_super_vox=Cluster_Super_Vox(min_touching_area=min_touching_area, min_touching_percentage=min_touching_percentage)
cluster_super_vox.fit(seg_foreground_super_voxel_by_ws)
seg_foreground_single_cell_with_boundary = cluster_super_vox.output_3d_img
# Out:
# ll vals: 0.2876833362784944get val_outlayer area of all vals: 0.8176356246686693current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 31current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 36current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 186current_crop_outlayer_area: 303current_crop_outlayer_area: 268current_crop_outlayer_area: 331current_crop_outlayer_area: 20current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 106current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 183current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 487current_crop_outlayer_area: 623current_crop_outlayer_area: 134current_crop_outlayer_area: 125current_crop_outlayer_area: 95current_crop_outlayer_area: 0current_crop_outlayer_area: 105current_crop_outlayer_area: 0current_crop_outlayer_area: 261current_crop_outlayer_area: 0current_crop_outlayer_area: 194current_crop_outlayer_area: 9current_crop_outlayer_area: 336current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 294current_crop_outlayer_area: 283current_crop_outlayer_area: 85current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 150current_crop_outlayer_area: 0current_crop_outlayer_area: 8current_crop_outlayer_area: 8current_crop_outlayer_area: 9current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 154current_crop_outlayer_area: 0current_crop_outlayer_area: 301current_crop_outlayer_area: 1current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 105current_crop_outlayer_area: 0current_crop_outlayer_area: 275current_crop_outlayer_area: 195current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 582current_crop_outlayer_area: 582current_crop_outlayer_area: 294current_crop_outlayer_area: 309current_crop_outlayer_area: 274current_crop_outlayer_area: 206current_crop_outlayer_area: 24current_crop_outlayer_area: 22current_crop_outlayer_area: 2current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 627current_crop_outlayer_area: 193current_crop_outlayer_area: 0current_crop_outlayer_area: 157current_crop_outlayer_area: 144current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_outlayer_area: 256current_crop_outlayer_area: 243current_crop_outlayer_area: 57current_crop_outlayer_area: 0current_crop_outlayer_area: 171current_crop_outlayer_area: 0current_crop_outlayer_area: 0current_crop_o ...

# %%
plt.figure(figsize=(20,20))
plt.title("unprocessed TASCAN result")
plt.imshow(seg_foreground_single_cell_with_boundary[N,:,:])

# %% [markdown]
# delete too small cells

# %%
# Delete too small cells
min_cell_size_threshold=10

seg_foreground_single_cell_with_boundary_delete_too_small = delete_too_small_cluster(seg_foreground_single_cell_with_boundary, threshold=min_cell_size_threshold)

# %%
plt.figure(figsize=(20,20))
plt.title("after deleting too small cells")
plt.imshow(seg_foreground_single_cell_with_boundary_delete_too_small[N,:,:])

# %% [markdown]
# assign boudary voxels to their nearest cells

# %%
# Assign boudary voxels to their nearest cells
seg_final=assign_boudary_voxels_to_cells_with_watershed(seg_foreground_single_cell_with_boundary_delete_too_small, seg_boundary_comp, seg_background_comp, compactness=1)

# %%
plt.figure(figsize=(20,20))
plt.title("final segmentation")
plt.imshow(seg_final[N,:,:])

# %%
# Reassign unique numbers
seg_final=reassign(seg_final)
# Out:
# eassign unique numbers progress: 0.020017406440382943reassign unique numbers progress: 0.020887728459530026reassign unique numbers progress: 0.02175805047867711reassign unique numbers progress: 0.022628372497824196reassign unique numbers progress: 0.02349869451697128reassign unique numbers progress: 0.024369016536118365reassign unique numbers progress: 0.025239338555265448reassign unique numbers progress: 0.02610966057441253reassign unique numbers progress: 0.026979982593559618reassign unique numbers progress: 0.0278503046127067reassign unique numbers progress: 0.028720626631853787reassign unique numbers progress: 0.02959094865100087reassign unique numbers progress: 0.030461270670147953reassign unique numbers progress: 0.031331592689295036reassign unique numbers progress: 0.03220191470844212reassign unique numbers progress: 0.03307223672758921reassign unique numbers progress: 0.033942558746736295reassign unique numbers progress: 0.034812880765883375reassign unique numbers progress: 0.03568320278503046reassign unique numbers progress: 0.03655352480417755reassign unique numbers progress: 0.03742384682332463reassign unique numbers progress: 0.038294168842471714reassign unique numbers progress: 0.0391644908616188reassign unique numbers progress: 0.04003481288076589reassign unique numbers progress: 0.040905134899912966reassign unique numbers progress: 0.04177545691906005reassign unique numbers progress: 0.04264577893820714reassign unique numbers progress: 0.04351610095735422reassign unique numbers progress: 0.044386422976501305reassign unique numbers progress: 0.04525674499564839reassign unique numbers progress: 0.04612706701479547reassign unique numbers progress: 0.04699738903394256reassign unique numbers progress: 0.047867711053089644reassign unique numbers progress: 0.04873803307223673reassign unique numbers progress: 0.04960835509138381reassign unique numbers progress: 0.050478677110530897reassign unique numbers progress: 0.05134899912967798reassign unique numbers progress: 0.05221932114882506reassign unique numbers progress: 0.05308964316797215reassign unique numbers progress: 0.053959965187119235reassign unique numbers progress: 0.05483028720626632reassign unique numbers progress: 0.0557006092254134reassign unique numbers progress: 0.05657093124456049reassign unique numbers progress: 0.057441253263707574reassign unique numbers progress: 0.058311575282854654reassign unique numbers progress: 0.05918189730200174reassign unique numbers progress: 0.06005221932114883reassign unique numbers progress: 0.060922541340295906reassign unique numbers progress: 0.06179286335944299reassign unique numbers progress: 0.06266318537859007reassign unique numbers progress: 0.06353350739773717reassign unique numbers progress: 0.06440382941688425reassign unique numbers progress: 0.06527415143603134reassign unique numbers progress: 0.06614447345517842reassign unique numbers progress: 0.0670147954743255reassign unique numbers progress: 0.06788511749347259reassign unique numbers progress: 0.06875543951261967reassign unique numbers progress: 0.06962576153176675reassign unique numbers progress: 0.07049608355091384reassign unique numbers progress: 0.07136640557006092reassign unique numbers progress: 0.072236727589208reassign unique numbers progress: 0.0731070496083551reassign unique numbers progress: 0.07397737162750218reassign unique numbers progress: 0.07484769364664925reassign unique numbers progress: 0.07571801566579635reassign unique numbers progress: 0.07658833768494343reassign unique numbers progress: 0.07745865970409051reassign unique numbers progress: 0.0783289817232376reassign unique numbers progress: 0.07919930374238468reassign unique numbers progress: 0.08006962576153177reassign unique numbers progress: 0.08093994778067885reassign unique numbers progress: 0.08181026979982593reassign unique numbers progress: 0.08268059181897303reassign unique numbers progress: 0.0835509138381201reassign unique numbers progress: 0.08442123585726719reassign unique ...

# %% [markdown]
# Evaluate with Metrics

# %%
import func.cal_accuracy

iou_and_dice_accuracy = IOU_and_Dice_Accuracy(hand_seg, seg_final)

# %%
accuracy_result = iou_and_dice_accuracy.cal_accuracy()
# Out:
# progress: 4.013104013104013%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 accuracy_result = iou_and_dice_accuracy.cal_accuracy()
#
# File ~/Documents/GitHub/3DCellSegMasterThesis/func/cal_accuracy.py:67, in IOU_and_Dice_Accuracy.cal_accuracy(self)
#      64 masks_gt_crop = np.expand_dims(gt_crop==value, axis=3)
#      65 masks_pred_crop = self.get_masks(pred_crop, candidates)
# ---> 67 overlaps, dices = self.compute_overlaps_masks(masks_gt_crop, masks_pred_crop)
#      68 idx = np.argmax(overlaps)
#      70 iou = overlaps[0,idx]
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# see the final result

# %%
N=80
# print("There are "+str(len(np.unique(seg_final)))+" cells in model prediction")
# print("There are "+str(len(np.unique(hand_seg)))+" cells in hand seg")
plt.figure()
plt.title("raw_img")
plt.imshow(raw_img[N,:,:])
plt.figure()
plt.title("hand_seg")
plt.imshow(reassign(hand_seg[N,:,:]))
plt.figure()
plt.title("model_seg")
plt.imshow(reassign(seg_final[N,:,:]))
# Out:
# reassign unique numbers progress: 0.9961538461538462764

# %%
def colorful_seg(seg):
    unique_vals, val_counts = np.unique(seg, return_counts=True)
    
    background_val = unique_vals[np.argsort(val_counts)[::-1][0]]
    
    seg_RGB = []
    for i in range(seg.shape[0]):
        mask_gray = cv2.normalize(src=seg[i,:,:], dst=None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8UC1)
        seg_slice_RGB = cv2.cvtColor(mask_gray, cv2.COLOR_GRAY2RGB)
        seg_RGB.append(seg_slice_RGB)
    seg_RGB = np.array(seg_RGB)
    
    for idx, unique_val in enumerate(unique_vals):
        print(str(idx/len(unique_vals)), end="\r")
        if unique_val == background_val:
            COLOR = np.array([0,0,0], dtype=int)
        else:
            COLOR = np.array(np.random.choice(np.arange(256), size=3, replace=False), dtype=int)
        
        locs = np.where(seg==unique_val)
        
        for i in range(3):
            seg_RGB[locs[0], locs[1], locs[2], i] = COLOR[i]
        
    return seg_RGB

# %%
seg_final_RGB = colorful_seg(seg_final)
hand_seg_RGB = colorful_seg(hand_seg)
# Out:
# 0.9991749174917491346

# %%
N=80

fig = plt.figure(figsize=(5,5))
plt.axis('off')
plt.imshow(seg_final_RGB[N,:,:])
#plt.savefig('Ovules_seg_RGB_'+str(N)+'.png',bbox_inches='tight',dpi=fig.dpi,pad_inches=0.0)
