# %%
from func.ultis import decompress_pickle
import matplotlib.pyplot as plt

from func.run_pipeline_super_vox import reassign

# %%
seg_final_HMS = decompress_pickle("../../masterthesis_results/HMS/edge_gated_gcn/65_seg_final.pbz2")
N=80

plt.figure()
plt.title("seg_final HMS")
plt.imshow(reassign(seg_final_HMS[N,:,:]))
# Out:
# 5

# %%
seg_final_HMS = decompress_pickle("../../masterthesis_results/HMS/original_groupnorm/65_seg_final.pbz2")
N=80

plt.figure()
plt.title("seg_final HMS")
plt.imshow(reassign(seg_final_HMS[N,:,:]))
# Out:
# 5

# %%
seg_final_HMS = decompress_pickle("../../masterthesis_results/HMS/gasp/65_seg_final.pbz2")
N=80

plt.figure()
plt.title("seg_final HMS")
plt.imshow(reassign(seg_final_HMS[N,:,:]))
# Out:
# 6

# %%
seg_final_HMS = decompress_pickle("../../masterthesis_results/HMS/edge_gated_gcn/65_seg_foreground_super_voxel_by_ws.pbz2")
N=80

plt.figure()
plt.title("seg_foreground_supervoxel_by_ws HMS")
plt.imshow(reassign(seg_final_HMS[N,:,:]))
# Out:
# 6

# %%
seg_final_HMS = decompress_pickle("../../masterthesis_results/HMS/original_groupnorm/65_seg_foreground_super_voxel_by_ws.pbz2")
N=80

plt.figure()
plt.title("seg_foreground_supervoxel_by_ws HMS")
plt.imshow(reassign(seg_final_HMS[N,:,:]))
# Out:
# 5

# %% [markdown]
# ##### lrp

# %%
seg_final_HMS = decompress_pickle("../../masterthesis_results/lrp_results/edge_gated_gcn/Movie1_t00006_crop_gt.h5_seg_final.pbz2")
N=80

plt.figure()
plt.title("seg_final LRP")
plt.imshow(reassign(seg_final_HMS[N,:,:]))
# Out:
# 6

# %%
seg_final_HMS = decompress_pickle("../../masterthesis_results/lrp_results/retrained/Movie1_t00006_crop_gt.h5_seg_final.pbz2")
N=80

plt.figure()
plt.title("seg_final LRP")
plt.imshow(reassign(seg_final_HMS[N,:,:]))
# Out:
# reassign unique numbers progress: 0.9166666666666666

# %%
seg_final_HMS = decompress_pickle("../../masterthesis_results/lrp_results/gasp/Movie1_t00006_crop_gt.h5_seg_final.pbz2")
N=80

plt.figure()
plt.title("seg_final LRP")
plt.imshow(reassign(seg_final_HMS[N,:,:]))
# Out:
# reassign unique numbers progress: 0.9
