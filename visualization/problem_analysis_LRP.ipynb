# ...

# %%
hf = h5py.File("../data/CellSeg_dataset/LateralRootPrimordia_processed_wide_boundary_non_precropped/test/Movie1_t00006_crop_gt.h5", 'r')
print(hf.keys())
raw_img = np.array(hf["raw"], dtype=np.float)
hand_seg = np.array(hf["ins"], dtype=np.float)
# boundary_gt = np.array(hf["boundary"], dtype=np.float)
# background_gt = np.array(hf["background"], dtype=np.float)
# foreground_gt = np.array(hf["foreground"], dtype=np.float)

seg_final_lrp_gt_colorful = colorful_seg(hand_seg)
# Out:
# <KeysViewHDF5 ['background', 'boundary', 'edge_background', 'edge_boundary', 'edge_foreground', 'foreground', 'ins', 'raw']>
# /var/folders/qq/9q6wphrj19z8xt4qcffm8df80000gn/T/ipykernel_31316/3479042271.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   raw_img = np.array(hf["raw"], dtype=np.float)
# /var/folders/qq/9q6wphrj19z8xt4qcffm8df80000gn/T/ipykernel_31316/3479042271.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %%
N=120

plt.figure(dpi=200)
# plt.title("seg_final lrp")
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelbottom=False, left=False, labelleft=False)
plt.imshow(reassign(seg_final_lrp_eg_gcn_colorful[:,:,N]))
plt.savefig("outputs/final_seg_eg_gcn_LRP_1.pdf", bbox_inches='tight')
# Out:
# reassign unique numbers progress: 0.9868421052631579

# %%
N=120

plt.figure(dpi=200)
# plt.title("seg_final lrp")
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelbottom=False, left=False, labelleft=False)
plt.imshow(reassign(seg_final_lrp_eg_tascan_colorful[:,:,N]))
plt.savefig("outputs/final_seg_eg_tascan_LRP_1.pdf", bbox_inches='tight')
# Out:
# 4reassign unique numbers progress: 0.8083333333333333

# %%
N=120

plt.figure(dpi=200)
# plt.title("gt lrp")
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelbottom=False, left=False, labelleft=False)
plt.imshow(seg_final_lrp_gt_colorful[:,:,N])
plt.savefig("outputs/gt_LRP_1.pdf", bbox_inches='tight')

# %%
N=120

plt.figure(dpi=200)
# plt.title("raw lrp")
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelbottom=False, left=False, labelleft=False)
plt.imshow(raw_img[:,:,N])
plt.savefig("outputs/raw_img_LRP_1.pdf", bbox_inches='tight')

# %%
N=120

plt.figure(dpi=200)
# plt.title("supervoxel lrp")
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelbottom=False, left=False, labelleft=False)
plt.imshow(reassign(super_voxel_by_ws_lrp_eg_colorful[:,:,N]))
plt.savefig("outputs/super_voxel_LRP_1.pdf", bbox_inches='tight')
# Out:
# reassign unique numbers progress: 0.996
