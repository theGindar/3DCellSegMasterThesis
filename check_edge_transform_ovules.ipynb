# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
images = np.load("data/CellSeg_dataset/Ovules_processed_thin_boundary_edge/train/N_404_ds2x.npz")

# %%
for f in images.files:
    print(f)
# Out:
# raw
# ins
# boundary
# foreground
# background_edge
# boundary_edge
# foreground_edge

# %%
background_edge = images['background_edge']
boundary_edge = images['boundary_edge']
foreground_edge = images['foreground_edge']
foreground = images['foreground']

# %%
background_edge.shape
# Out:
# (160, 281, 484)

# %%
plt.figure(figsize=(10,10))
plt.title("background_edge")
plt.imshow(background_edge[80,:,:])

plt.figure(figsize=(10,10))
plt.title("boundary_edge")
plt.imshow(boundary_edge[80,:,:])

plt.figure(figsize=(10,10))
plt.title("foreground_edge")
plt.imshow(foreground_edge[80,:,:])

plt.figure(figsize=(10,10))
plt.title("foreground")
plt.imshow(foreground[80,:,:])
