# %%
import pandas as pd
import numpy as np
from func.ultis import load_obj

# %%
pretrained = pd.read_csv('output/results_test_model_Ovules.csv')
pretrained_2 = pd.read_csv('output/results_test_model_Ovules_2.csv')
pretrained_3 = pd.read_csv('output/results_test_model_Ovules_3.csv')
retrained = pd.read_csv('output/results_test_model_Ovules_retrained.csv')
retrained_2 = pd.read_csv('output/results_test_model_Ovules_retrained_control_background_2.csv')

edge_gated = pd.read_csv('output/results_test_model_Ovules_edge_gated.csv')
edge_gated_2 = pd.read_csv('output/results_test_model_Ovules_edge_gated_2.csv')

# %%
retrained_2.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    7.000000     7.000000     7.000000      7.000000      7.000000
# mean     3.000000     0.653199     0.735663      0.716353      0.839469
# std      2.160247     0.079468     0.072561      0.073963      0.063124
# min      0.000000     0.517241     0.603448      0.581379      0.735862
# 25%      1.500000     0.608244     0.703267      0.684222      0.808944
# 50%      3.000000     0.674858     0.750473      0.731569      0.830813
# 75%      4.500000     0.709274     0.785689      0.765880      0.884196
# max      6.000000     0.745260     0.817807      0.801319      0.923331
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.696241  0.776599  0.675481  0.568909
# std    0.060826  0.055834  0.108276  0.196325
# min    0.591817  0.680684  0.505635  0.380782
# 25%    0.660900  0.745238  0.615938  0.414272
# ...

# %%
edge_gated_2.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    7.000000     7.000000     7.000000      7.000000      7.000000
# mean     3.000000     0.688893     0.773931      0.757516      0.861961
# std      2.160247     0.062650     0.051461      0.052141      0.045468
# min      0.000000     0.611724     0.720690      0.700000      0.815172
# 25%      1.500000     0.639518     0.733346      0.719308      0.824511
# 50%      3.000000     0.686200     0.757089      0.738185      0.844045
# 75%      4.500000     0.731054     0.808658      0.792049      0.898604
# max      6.000000     0.783182     0.855730      0.841715      0.928277
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.708600  0.789680  0.782052  0.507811
# std    0.049705  0.045212  0.101349  0.113396
# min    0.637059  0.726356  0.686997  0.392853
# 25%    0.670778  0.755569  0.731265  0.412448
# ...

# %%
edge_gated.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    7.000000     7.000000     7.000000      7.000000      7.000000
# mean     3.000000     0.710153     0.786978      0.769861      0.873347
# std      2.160247     0.049141     0.040834      0.043534      0.032286
# min      0.000000     0.628746     0.723853      0.707034      0.825076
# 25%      1.500000     0.679766     0.759294      0.735774      0.856345
# 50%      3.000000     0.730345     0.802759      0.790553      0.868276
# 75%      4.500000     0.742465     0.812614      0.798981      0.891204
# max      6.000000     0.767519     0.838417      0.821929      0.924979
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.724285  0.801830  0.710399  0.503659
# std    0.034721  0.032547  0.097746  0.096201
# min    0.671733  0.754001  0.584850  0.395295
# 25%    0.704936  0.783845  0.651643  0.422143
# ...

# %%
pretrained.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    7.000000     7.000000     7.000000      7.000000      7.000000
# mean     3.000000     0.692896     0.769088      0.754502      0.850348
# std      2.160247     0.058281     0.048739      0.047014      0.039574
# min      0.000000     0.606422     0.702446      0.688073      0.801529
# 25%      1.500000     0.659844     0.737531      0.726116      0.823324
# 50%      3.000000     0.694483     0.767586      0.755862      0.840580
# 75%      4.500000     0.724896     0.797166      0.778410      0.875945
# max      6.000000     0.779885     0.844188      0.828524      0.911789
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.715036  0.790356  0.778074  0.505492
# std    0.041414  0.039402  0.110204  0.107328
# min    0.659064  0.739660  0.604421  0.386251
# 25%    0.691008  0.766295  0.708824  0.421603
# ...

# %%
retrained_2
# Out:
#    Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5   avg_iou  \
# 0           0     0.615596     0.706422      0.691743      0.801835  0.666749
# 1           1     0.705882     0.788770      0.771836      0.891266  0.747851
# 2           2     0.517241     0.603448      0.581379      0.735862  0.591817
# 3           3     0.745260     0.817807      0.801319      0.923331  0.758991
# 4           4     0.674858     0.750473      0.731569      0.830813  0.714740
# 5           5     0.600892     0.700111      0.676700      0.816054  0.655051
# 6           6     0.712665     0.782609      0.759924      0.877127  0.738489
#
#    avg_dice     voi_1     voi_2
# 0  0.746703  0.680990  0.646065
# 1  0.821406  0.624500  0.389164
# 2  0.680684  0.505635  0.921762
# 3  0.837732  0.607376  0.518772
# 4  0.788808  0.755801  0.380782
# 5  0.743772  0.836824  0.686436
# 6  0.817089  0.717245  0.439380

# %%
retrained_2.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    7.000000     7.000000     7.000000      7.000000      7.000000
# mean     3.000000     0.653199     0.735663      0.716353      0.839469
# std      2.160247     0.079468     0.072561      0.073963      0.063124
# min      0.000000     0.517241     0.603448      0.581379      0.735862
# 25%      1.500000     0.608244     0.703267      0.684222      0.808944
# 50%      3.000000     0.674858     0.750473      0.731569      0.830813
# 75%      4.500000     0.709274     0.785689      0.765880      0.884196
# max      6.000000     0.745260     0.817807      0.801319      0.923331
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.696241  0.776599  0.675481  0.568909
# std    0.060826  0.055834  0.108276  0.196325
# min    0.591817  0.680684  0.505635  0.380782
# 25%    0.660900  0.745238  0.615938  0.414272
# ...

# %%
retrained_2.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    7.000000     7.000000     7.000000      7.000000      7.000000
# mean     3.000000     0.653199     0.735663      0.716353      0.839469
# std      2.160247     0.079468     0.072561      0.073963      0.063124
# min      0.000000     0.517241     0.603448      0.581379      0.735862
# 25%      1.500000     0.608244     0.703267      0.684222      0.808944
# 50%      3.000000     0.674858     0.750473      0.731569      0.830813
# 75%      4.500000     0.709274     0.785689      0.765880      0.884196
# max      6.000000     0.745260     0.817807      0.801319      0.923331
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.696241  0.776599  0.675481  0.568909
# std    0.060826  0.055834  0.108276  0.196325
# min    0.591817  0.680684  0.505635  0.380782
# 25%    0.660900  0.745238  0.615938  0.414272
# ...

# %%
retrained_3 = retrained_2.drop([2])

# %%
retrained_3.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    6.000000     6.000000     6.000000      6.000000      6.000000
# mean     3.166667     0.675859     0.757699      0.738849      0.856737
# std      2.316607     0.057141     0.047322      0.048103      0.047716
# min      0.000000     0.600892     0.700111      0.676700      0.801835
# 25%      1.500000     0.630412     0.717435      0.701700      0.819743
# 50%      3.500000     0.690370     0.766541      0.745747      0.853970
# 75%      4.750000     0.710970     0.787230      0.768858      0.887731
# max      6.000000     0.745260     0.817807      0.801319      0.923331
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.713645  0.792585  0.703789  0.510100
# std    0.043537  0.039929  0.085658  0.131153
# min    0.655051  0.743772  0.607376  0.380782
# 25%    0.678747  0.757229  0.638622  0.401718
# ...

# %%
retrained_3.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    6.000000     6.000000     6.000000      6.000000      6.000000
# mean     3.166667     0.675859     0.757699      0.738849      0.856737
# std      2.316607     0.057141     0.047322      0.048103      0.047716
# min      0.000000     0.600892     0.700111      0.676700      0.801835
# 25%      1.500000     0.630412     0.717435      0.701700      0.819743
# 50%      3.500000     0.690370     0.766541      0.745747      0.853970
# 75%      4.750000     0.710970     0.787230      0.768858      0.887731
# max      6.000000     0.745260     0.817807      0.801319      0.923331
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.713645  0.792585  0.703789  0.510100
# std    0.043537  0.039929  0.085658  0.131153
# min    0.655051  0.743772  0.607376  0.380782
# 25%    0.678747  0.757229  0.638622  0.401718
# ...

# %%
pretrained.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    7.000000     7.000000     7.000000      7.000000      7.000000
# mean     3.000000     0.692896     0.769088      0.754502      0.850348
# std      2.160247     0.058281     0.048739      0.047014      0.039574
# min      0.000000     0.606422     0.702446      0.688073      0.801529
# 25%      1.500000     0.659844     0.737531      0.726116      0.823324
# 50%      3.000000     0.694483     0.767586      0.755862      0.840580
# 75%      4.500000     0.724896     0.797166      0.778410      0.875945
# max      6.000000     0.779885     0.844188      0.828524      0.911789
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.715036  0.790356  0.778074  0.505492
# std    0.041414  0.039402  0.110204  0.107328
# min    0.659064  0.739660  0.604421  0.386251
# 25%    0.691008  0.766295  0.708824  0.421603
# ...

# %%
pretrained_2.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    7.000000     7.000000     7.000000      7.000000      7.000000
# mean     3.000000     0.690393     0.761736      0.745751      0.843733
# std      2.160247     0.059777     0.051561      0.051776      0.048021
# min      0.000000     0.602071     0.690237      0.674260      0.784320
# 25%      1.500000     0.661730     0.733338      0.717439      0.805180
# 50%      3.000000     0.680263     0.754675      0.734873      0.843784
# 75%      4.500000     0.722531     0.788060      0.775364      0.876630
# max      6.000000     0.781893     0.844444      0.825514      0.914403
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.704877  0.780997  0.746276  0.519424
# std    0.048242  0.046714  0.103408  0.109741
# min    0.640494  0.721427  0.586577  0.396084
# 25%    0.674893  0.749121  0.681401  0.437749
# ...

# %%
retrained
# Out:
#    Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5   avg_iou  \
# 0           0     0.595719     0.696024      0.671254      0.799388  0.655435
# 1           1     0.635472     0.738859      0.713904      0.860963  0.703816
# 2           2     0.313103     0.428966      0.395862      0.612414  0.471139
# 3           3     0.712284     0.785655      0.769992      0.895301  0.731051
# 4           4     0.633270     0.722117      0.696597      0.827977  0.689994
# 5           5     0.515050     0.610925      0.589744      0.778149  0.599305
# 6           6     0.621928     0.722117      0.700378      0.852552  0.693527
#
#    avg_dice     voi_1     voi_2
# 0  0.737991  0.680595  0.699979
# 1  0.788306  0.887912  0.486623
# 2  0.578587  0.683198  1.246311
# 3  0.816719  0.711006  0.590913
# 4  0.771815  0.761407  0.464377
# 5  0.697801  0.995114  0.795860
# 6  0.784462  0.872502  0.526498

# %%
retrained.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    7.000000     7.000000     7.000000      7.000000      7.000000
# mean     3.000000     0.575261     0.672095      0.648247      0.803821
# std      2.160247     0.129559     0.119572      0.123719      0.093012
# min      0.000000     0.313103     0.428966      0.395862      0.612414
# 25%      1.500000     0.555384     0.653475      0.630499      0.788769
# 50%      3.000000     0.621928     0.722117      0.696597      0.827977
# 75%      4.500000     0.634371     0.730488      0.707141      0.856757
# max      6.000000     0.712284     0.785655      0.769992      0.895301
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.649181  0.739383  0.798819  0.687223
# std    0.089018  0.080669  0.121350  0.273725
# min    0.471139  0.578587  0.680595  0.464377
# 25%    0.627370  0.717896  0.697102  0.506561
# ...

# %%
pretrained_2 = pretrained.drop([4])

# %%
pretrained_2.describe()
# Out:
#        Unnamed: 0  acc_iou_0_7  acc_iou_0_5  acc_dice_0_7  acc_dice_0_5  \
# count    6.000000     6.000000     6.000000      6.000000      6.000000
# mean     2.833333     0.700470     0.776286      0.760844      0.856597
# std      2.316607     0.059950     0.049146      0.048108      0.039387
# min      0.000000     0.606422     0.702446      0.688073      0.801529
# 25%      1.250000     0.677801     0.753769      0.740805      0.835490
# 50%      2.500000     0.699737     0.775950      0.759838      0.853891
# 75%      4.500000     0.734849     0.803593      0.785708      0.880316
# max      6.000000     0.779885     0.844188      0.828524      0.911789
#
#         avg_iou  avg_dice     voi_1     voi_2
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.719208  0.794073  0.754841  0.517363
# std    0.043726  0.041797  0.100198  0.112425
# min    0.659064  0.739660  0.604421  0.386251
# 25%    0.693154  0.766303  0.697046  0.422366
# ...

# %% [markdown]
# # Bilder

# %%
# N_512_ds2x.npz ist problematisch
case = "N_512_ds2x.npz"

Ovules_data_dict = load_obj("dataset_info/Ovules_dataset_info")
Ovules_data_dict['train'][case]
# Out:
# 'data/CellSeg_dataset/Ovules_processed_thin_boundary_edge/train/N_512_ds2x.npz'

# %%
# hf = np.load(Ovules_data_dict['train'][case])
hf = np.load('../../N_512_ds2x.npz')
raw_img = np.array(hf["raw"], dtype=np.float)
hand_seg = np.array(hf["ins"], dtype=np.float)
boundary_gt = np.array(hf["boundary"], dtype=np.float)
foreground_gt = np.array(hf["foreground"], dtype=np.float)
# Out:
# /var/folders/qq/9q6wphrj19z8xt4qcffm8df80000gn/T/ipykernel_56558/3619418832.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   raw_img = np.array(hf["raw"], dtype=np.float)
# /var/folders/qq/9q6wphrj19z8xt4qcffm8df80000gn/T/ipykernel_56558/3619418832.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
import matplotlib.pyplot as plt

N=80
plt.figure()
plt.title("raw_img")
plt.imshow(raw_img[N,:,:])
plt.figure()
plt.figure()
plt.title("hand_seg")
plt.imshow(hand_seg[N,:,:])
plt.figure()
plt.title("foreground_gt")
plt.imshow(foreground_gt[N,:,:])
plt.figure()
plt.title("boundary_gt")
plt.imshow(boundary_gt[N,:,:])
plt.figure()

# %%
with open('../../debug_stuff/seg_output.npy', 'rb') as f:
    seg_output = np.load(f)
with open('../../debug_stuff/seg_groundtruth_f.npy', 'rb') as f:
    seg_groundtruth_f = np.load(f)
with open('../../debug_stuff/seg_groundtruth_ba.npy', 'rb') as f:
    seg_groundtruth_ba = np.load(f)
with open('../../debug_stuff/seg_groundtruth_bo.npy', 'rb') as f:
    seg_groundtruth_bo = np.load(f)

# %%
seg_output.shape
# Out:
# (3, 3, 64, 64, 64)

# %%
np.unique(seg_groundtruth_ba)
# Out:
# array([1.], dtype=float32)

# %%
np.unique(seg_groundtruth_bo)
# Out:
# array([0.], dtype=float32)

# %%
np.unique(seg_groundtruth_f)
# Out:
# array([0.], dtype=float32)

# %%
dataset_info_original = load_obj('Ovules_dataset_info_from_original')

# %%
type(dataset_info_original)
# Out:
# dict

# %%
print(dataset_info_original)
# Out:
# {'train': {'N_404_ds2x.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_404_ds2x.npz', 'N_422_ds2x.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_422_ds2x.npz', 'N_509_ds2x.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_509_ds2x.npz', 'N_454_ds2x.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_454_ds2x.npz', 'N_405_B_ds2x.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_405_B_ds2x.npz', 'N_536_ds2x.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_536_ds2x.npz', 'N_512_ds2x.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_512_ds2x.npz', 'N_449_ds2x.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_449_ds2x.npz', 'N_405_A_ds2x.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_405_A_ds2x.npz', 'N_451_ds2x.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_451_ds2x.npz', 'N_534_ds2x.npz': '/data/Cell
# ...

# %%
import pprint

pprint.pprint(dataset_info_original)
# Out:
# {'test': {'N_294_final_crop_ds2.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_294_final_crop_ds2.npz',
#           'N_435_final_crop_ds2.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_435_final_crop_ds2.npz',
#           'N_441_final_crop_ds2.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_441_final_crop_ds2.npz',
#           'N_511_final_crop_ds2.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_511_final_crop_ds2.npz',
#           'N_522_final_crop_ds2.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_522_final_crop_ds2.npz',
#           'N_590_final_crop_ds2.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_590_final_crop_ds2.npz',
#           'N_593_final_crop_ds2.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/test/N_593_final_crop_ds2.npz'},
#  'train': {'N_404_ds2x.npz': '/data/CellSeg_dataset/Ovules_processed_thin_boundary/train/N_404_ds2x.npz',
# ...
